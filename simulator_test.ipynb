# %%
from quantum_simulator import *

# %%
q = quantum_circuit(filename = "test.json")
# Out:
# applied [[ 0.70710678+0.j  0.70710678+0.j]
#  [ 0.70710678+0.j -0.70710678+0.j]]
# [[ 0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.70710678+0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.70710678+0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.70710678+0.j  0.        +0.j
#    0.        +0.j  0.        +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  0.        +0.j  0.70710678+0.j
# ...

# %%
results = []
for i in range(1000):
    results.append(q.run())
result_unique = set(results)
for i in result_unique:
    print(results.count(i))
# Out:
# [0, 1, 1, 1]

# %%
q.registers
# Out:
# array([[-0.6+0.j,  0. +0.j,  0. +0.j,  0. +0.j, -0.8+0.j,  0. +0.j,
#          0. +0.j,  0. +0.j,  0. +0.j,  0. +0.j,  0. +0.j,  0. +0.j,
#          0. +0.j,  0. +0.j,  0. +0.j,  0. +0.j]], dtype=complex128)

# %%
print(q.layers[0])
# Out:
# [[ 0. +0.j  0. +0.j  0. +0.j  0. +0.j  0.5+0.j  0. +0.j  0.5+0.j  0. +0.j
#    0. +0.j  0. +0.j  0. +0.j  0. +0.j  0.5+0.j  0. +0.j  0.5+0.j  0. +0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0.5+0.j  0. +0.j  0.5+0.j
#    0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0.5+0.j  0. +0.j  0.5+0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j  0.5+0.j  0. +0.j -0.5+0.j  0. +0.j
#    0. +0.j  0. +0.j  0. +0.j  0. +0.j  0.5+0.j  0. +0.j -0.5+0.j  0. +0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0.5+0.j  0. +0.j -0.5+0.j
#    0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0.5+0.j  0. +0.j -0.5+0.j]
#  [ 0.5+0.j  0. +0.j  0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j
#    0.5+0.j  0. +0.j  0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j]
#  [ 0. +0.j  0.5+0.j  0. +0.j  0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j
#    0. +0.j  0.5+0.j  0. +0.j  0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j]
#  [ 0.5+0.j  0. +0.j -0.5+0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j  0. +0.j
# ...

# %%
np.matmul(q.layers[0].matrix,q.registers.T)
# Out:
# array([[-0.4+0.j],
#        [ 0. +0.j],
#        [-0.4+0.j],
#        [ 0. +0.j],
#        [-0.3+0.j],
#        [ 0. +0.j],
#        [-0.3+0.j],
#        [ 0. +0.j],
#        [-0.4+0.j],
#        [ 0. +0.j],
#        [-0.4+0.j],
#        [ 0. +0.j],
#        [-0.3+0.j],
#        [ 0. +0.j],
#        [-0.3+0.j],
#        [ 0. +0.j]], dtype=complex128)

# %%
q.layers[0]
